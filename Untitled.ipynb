# %%
import spacy
from spacy import displacy
from collections import Counter
from pprint import pprint
import en_core_web_sm
nlp = en_core_web_sm.load()

# %%
# from bs4 import BeautifulSoup
# import requests
# import re
# def url_to_string(url):
#     res = requests.get(url)
#     html = res.text
#     soup = BeautifulSoup(html, 'html5lib')
#     for script in soup(["script", "style", 'aside']):
#         script.extract()
#     return " ".join(re.split(r'[\n\t]+', soup.get_text()))
# ny_bb = url_to_string('https://www.nytimes.com/2018/08/13/us/politics/peter-strzok-fired-fbi.html?hp&action=click&pgtype=Homepage&clickSource=story-heading&module=first-column-region&region=top-news&WT.nav=top-news')
# article = nlp(ny_bb)

# %%
article = nlp("""A suicide bomber rammed a car into a bus carrying Indian paramilitary police in Kashmir on Thursday (Feb 14), killing 44 of them in the deadliest attack in decades on security forces in the disputed region, raising tensions with arch foe Pakistan.

The Pakistan-based Islamist militant group Jaish-e-Mohammad (JeM) claimed responsibility for the attack. The Indian government accused Pakistan of letting militant groups operate from its soil and called on it to take action.

Islamabad said it rejected the suggestion it was linked to the attack""")

# %%
labels = [x.label_ for x in article.ents]
print(Counter(labels))
items = [x.text for x in article.ents]
print(Counter(items).most_common(3))
# sentences = [x for x in article.sents]
print([(X.text, X.label_) for X in article.ents])
# Out:
# Counter({'GPE': 4, 'NORP': 3, 'DATE': 3, 'LOC': 1, 'CARDINAL': 1, 'LANGUAGE': 1, 'ORG': 1})
# [('Pakistan', 3), ('Indian', 2), ('Kashmir', 1)]
# [('Indian', 'NORP'), ('Kashmir', 'LOC'), ('Thursday', 'DATE'), ('Feb 14', 'DATE'), ('44', 'CARDINAL'), ('decades', 'DATE'), ('Pakistan', 'GPE'), ('Pakistan', 'GPE'), ('Islamist', 'NORP'), ('Jaish', 'LANGUAGE'), ('Mohammad (JeM', 'ORG'), ('Indian', 'NORP'), ('Pakistan', 'GPE'), ('Islamabad', 'GPE')]

# %%
for token in article:
    print (token.text+"::"+token.tag_+"::"+token.ent_type_+"::"+token.pos_)
# Out:
# A::DT::::DET
# suicide::NN::::NOUN
# bomber::NN::::NOUN
# rammed::VBD::::VERB
# a::DT::::DET
# car::NN::::NOUN
# into::IN::::ADP
# a::DT::::DET
# bus::NN::::NOUN
# carrying::VBG::::VERB
# Indian::JJ::NORP::ADJ
# paramilitary::JJ::::ADJ
# police::NNS::::NOUN
# in::IN::::ADP
# Kashmir::NNP::LOC::PROPN
# on::IN::::ADP
# Thursday::NNP::DATE::PROPN
# (::-LRB-::::PUNCT
# Feb::NNP::DATE::PROPN
# 14::CD::DATE::NUM
# )::-RRB-::::PUNCT
# ,::,::::PUNCT
# killing::VBG::::VERB
# 44::CD::CARDINAL::NUM
# of::IN::::ADP
# them::PRP::::PRON
# in::IN::::ADP
# the::DT::::DET
# deadliest::JJS::::ADJ
# attack::NN::::NOUN
# in::IN::::ADP
# decades::NNS::DATE::NOUN
# on::IN::::ADP
# security::NN::::NOUN
# forces::NNS::::NOUN
# in::IN::::ADP
# the::DT::::DET
# disputed::VBN::::VERB
# region::NN::::NOUN
# ,::,::::PUNCT
# raising::VBG::::VERB
# tensions::NNS::::NOUN
# with::IN::::ADP
# arch::JJ::::ADJ
# foe::NN::::NOUN
# Pakistan::NNP::GPE::PROPN
# .::.::::PUNCT
#
#
# ::_SP::::SPACE
# The::DT::::DET
# ...

# %%
displacy.render(nlp(str(sentences[20])), style='dep', jupyter = True, options = {'distance': 120})
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="624-0" class="displacy" width="890" height="377.0" style="max-width: none; height: 377.0px; color: #000000; background: #ffffff; font-family: Arial">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">PLUS</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">EMPOWER</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">FRIDAY</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">PROPN</tspan>
# ...

# %%
[(x.orth_,x.pos_, x.lemma_) for x in [y 
                                      for y
                                      in nlp(str(sentences[20])) 
                                      if not y.is_stop and y.pos_ != 'PUNCT']]
# Out:
# [('PLUS', 'PROPN', 'plus'),
#  ('EMPOWER', 'PROPN', 'empower'),
#  ('FRIDAY', 'PROPN', 'friday'),
#  ('REVIEW', 'PROPN', 'review'),
#  ('LITERARY', 'PROPN', 'literary'),
#  ('REVIEW', 'ADV', 'review'),
#  ('METRO', 'NOUN', 'metro')]

# %%
dict([(str(x), x.label_) for x in nlp(str(sentences[20])).ents])
# Out:
# {'PLUS EMPOWER FRIDAY REVIEW LITERARY REVIEW': 'ORG'}

# %%
displacy.render(article, jupyter=True, style='ent')
# Out:
# <div class="entities" style="line-height: 2.5"> The
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Nawabs
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  played
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Holi - NorthIndia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  - The
# ...
